# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("data/Austin_For_Sale.csv")

# %%
df.head()
# Out:
#                                         property_url   mls   mls_id    status  \
# 0  https://www.realtor.com/realestateandhomes-det...  AUTX  3768128  FOR_SALE
# 1  https://www.realtor.com/realestateandhomes-det...  AUTX  4548107  FOR_SALE
# 2  https://www.realtor.com/realestateandhomes-det...  AUTX  4842495  FOR_SALE
# 3  https://www.realtor.com/realestateandhomes-det...  AUTX  2382330  FOR_SALE
# 4  https://www.realtor.com/realestateandhomes-det...  AUTX  2177019  FOR_SALE
#
#                                                 text          style  \
# 0  This custom home, crafted by the award-winning...  SINGLE_FAMILY
# 1  This stunning one-story is nestled in a highly...  SINGLE_FAMILY
# 2  UP TO $5000 CREDIT TOWARDS BUYERS CLOSING COST...         CONDOS
# 3  Welcome to your dream home in the coveted Shad...  SINGLE_FAMILY
# 4  ZILKER New Construction with POOL- Walkable Lo...  SINGLE_FAMILY
#
#           full_street_line               street    unit    city state  \
# 0        2806 Geronimo Trl    2806 Geronimo Trl     NaN  Austin    TX
# 1      11904 Montclair Bnd  11904 Montclair Bnd     NaN  Austin    TX
# 2  6715 Windrift Way Apt 1    6715 Windrift Way   Apt 1  Austin    TX
# 3             3215 Doe Run         3215 Doe Run     NaN  Austin    TX
# 4     1604 Nash Ave Unit A        1604 Nash Ave  Unit A  Austin    TX
#
#    zip_code  beds  full_baths  half_baths    sqft  year_built  days_on_mls  \
# 0     78734   3.0         2.0         1.0  2614.0      2022.0            0
# 1     78732   4.0         2.0         NaN  2584.0      2008.0            0
# 2     78745   3.0         2.0         1.0  2067.0      2007.0            0
# 3     78748   3.0         2.0         1.0  1800.0      1987.0            0
# 4     78704   4.0         3.0         1.0  2200.0      2023.0            0
#
#    list_price   list_date  sold_price last_sold_date  assessed_value  \
# 0     1140000  2024-07-04         NaN            NaN        212553.0
# 1      670000  2024-07-04         NaN            NaN        528803.0
# 2      439500  2024-07-04         NaN            NaN        444474.0
# 3      540000  2024-07-04         NaN            NaN        739826.0
# 4     1500000  2024-07-04         NaN            NaN             NaN
#
#    estimated_value  lot_sqft  price_per_sqft   latitude  longitude  \
# 0         799613.0   10515.0           436.0  30.380731 -97.921348
# 1         671327.0    7200.0           259.0  30.341949 -97.910798
# 2         445200.0    5576.0           213.0  30.200230 -97.797478
# 3         580185.0   15581.0           300.0  30.171326 -97.850611
# 4              NaN    6848.0           682.0  30.252541 -97.768639
#
#                                 neighborhoods  county  fips_code  stories  \
# 0                               Apache Shores  Travis    48453.0      3.0
# 1  Bella Mar, Northwest Austin, Steiner Ranch  Travis    48453.0      1.0
# 2                 South Austin, Garrison Park  Travis    48453.0      2.0
# 3                                         NaN  Travis    48453.0      1.0
# 4                          Zilker, South Lawn  Travis    48453.0      3.0
#
#    hoa_fee  parking_garage               agent  \
# 0      8.0             2.0     Viktoriia Jones
# 1     88.0             2.0  Christoper Krueger
# 2    300.0             2.0       Renee Kennedy
# 3     47.0             2.0        Blake Carter
# 4      0.0             1.0     Kristee Leonard
#
#                       agent_email  \
# 0       Viktoriia.jones@yahoo.com
# 1                ckrueger3@me.com
# 2  renee@platinumrealtyaustin.com
# 3   blakedoesrealestate@gmail.com
# 4    kristee@theleadersrealty.com
#
#                                         agent_phones  \
# 0  [{'number': '5124663299', 'type': 'Mobile', 'e...
# 1  [{'number': '(512) 844-9198', 'type': 'BUSINES...
# 2  [{'number': '4807100344', 'type': 'Mobile', 'e...
# 3  [{'number': '5122005327', 'type': 'Mobile', 'e...
# 4  [{'number': '5126955144', 'type': 'Mobile', 'e...
#
#                                   broker    broker_phone  \
# 0  @ PROPERTIES CHRISTIE'S INTERNATIONAL  (512) 743-7820
# 1                      Epique Realty LLC  (512) 387-0722
# 2                             PMI Austin  (855) 446-4280
# 3                       MODUS Texas, LLC  (512) 920-5653
# 4                The Leaders Realty, Llc  (512) 695-5144
#
#                             broker_website  \
# 0  http://www.austinhomesearch.com/3768128
# 1  http://www.austinhomesearch.com/4548107
# 2  http://www.austinhomesearch.com/4842495
# 3  http://www.austinhomesearch.com/2382330
# 4  http://www.austinhomesearch.com/2177019
#
#                                       nearby_schools  \
# 0            Lake Travis Independent School District
# 1                Leander Independent School District
# 2  Wayside Schools, University Of Texas Universit...
# 3  University Of Texas University Charter School,...
# 4                 Austin Independent School District
#
#                                        primary_photo  \
# 0  http://ap.rdcpix.com/b37a694527306c77a4e45d988...
# 1  http://ap.rdcpix.com/57a17ae2537573fdfd4281870...
# 2                                                NaN
# 3  http://ap.rdcpix.com/75d2e9652917184ec0c2ea747...
# 4  http://ap.rdcpix.com/f6bc2c1010f2a9bd1615f93e7...
#
#                                           alt_photos
# 0  http://ap.rdcpix.com/b37a694527306c77a4e45d988...
# 1  http://ap.rdcpix.com/57a17ae2537573fdfd4281870...
# 2                                                NaN
# 3  http://ap.rdcpix.com/75d2e9652917184ec0c2ea747...
# 4  http://ap.rdcpix.com/f6bc2c1010f2a9bd1615f93e7...

# %% [markdown]
# # FOR SALE PROPERTY BASIC METRICS:

# %%
print("AUSTIN FOR SALE PROPERTY AVERAGES: \n")

print("Beds: "+ str(df.beds.mean().round(3)))
print("Full Baths: "+str(df.full_baths.mean().round(3)))
print("Half Baths: "+str(df.half_baths.mean().round(3)))
print("Square Feet: "+str(df.sqft.mean().round(3)))
print("Year Built: "+str(df.year_built.mean().round(3)))
print("Days on MLS: "+str(df.days_on_mls.mean().round(3)))
print("List Price: "+str(df.list_price.mean().round(3)))
print("Assessed Value: "+str(df.assessed_value.mean().round(3)))
print("Estimated Value: "+str(df.estimated_value.mean().round(3)))
print("Lot Square Feet: "+str(df.lot_sqft.mean().round(3)))
print("Price per Sq Feet: "+str(df.price_per_sqft.mean().round(3)))
print("Stories: "+str(df.stories.mean().round(3)))
print("HOA Fees: "+str(df.hoa_fee.mean().round(3)))
print("Parking Garage: "+str(df.parking_garage.mean().round(3)))
# Out:
# AUSTIN FOR SALE PROPERTY AVERAGES:
#
# Beds: 3.29
# Full Baths: 2.402
# Half Baths: 1.081
# Square Feet: 2191.703
# Year Built: 1996.315
# Days on MLS: 83.675
# List Price: 1011760.605
# Assessed Value: 651843.849
# Estimated Value: 1003223.497
# Lot Square Feet: 23924.604
# Price per Sq Feet: 432.818
# Stories: 1.604
# HOA Fees: 134.204
# Parking Garage: 2.078

# %%
print("AUSTIN FOR SALE PROPERTY DATASET MEDIANS: \n")

print("Beds: "+ str(df.beds.median().round(3)))
print("Full Baths: "+str(df.full_baths.median().round(3)))
print("Half Baths: "+str(df.half_baths.median().round(3)))
print("Square Feet: "+str(df.sqft.median().round(3)))
print("Year Built: "+str(int(df.year_built.median())))
print("Days on MLS: "+str(df.days_on_mls.median().round(3)))
print("List Price: "+str(df.list_price.median().round(3)))
print("Assessed Value: "+str(df.assessed_value.median().round(3)))
print("Estimated Value: "+str(df.estimated_value.median().round(3)))
print("Lot Square Feet: "+str(df.lot_sqft.median().round(3)))
print("Price per Sq Feet: "+str(df.price_per_sqft.median().round(3)))
print("Stories: "+str(df.stories.median().round(3)))
print("HOA Fees: "+str(df.hoa_fee.median().round(3)))
print("Parking Garage: "+str(df.parking_garage.median().round(3)))
# Out:
# AUSTIN FOR SALE PROPERTY DATASET MEDIANS:
#
# Beds: 3.0
# Full Baths: 2.0
# Half Baths: 1.0
# Square Feet: 1924.0
# Year Built: 2003
# Days on MLS: 57.0
# List Price: 625000.0
# Assessed Value: 492489.0
# Estimated Value: 629600.0
# Lot Square Feet: 7841.0
# Price per Sq Feet: 352.0
# Stories: 2.0
# HOA Fees: 27.0
# Parking Garage: 2.0

# %%
df["style"].value_counts()
# Out:
# style
# SINGLE_FAMILY    4566
# CONDOS           1409
# LAND              542
# TOWNHOMES         204
# MULTI_FAMILY      196
# MOBILE             56
# FARM               15
# Name: count, dtype: int64

# %%
df["neighborhoods"].value_counts()
# Out:
# neighborhoods
# Bluff Springs, Southeast Austin                    192
# Southeast Austin                                   167
# Apache Shores                                       73
# Greater South River City, Bouldin Creek             73
# South Lamar, South Lawn                             69
#                                                   ...
# Bar-K Ranches                                        1
# Chestnut, East Austin, Five Acres                    1
# Northvale, North Loop, Ridgetop, Central Austin      1
# Hillside Vista                                       1
# Foothills of Barton Creek                            1
# Name: count, Length: 1287, dtype: int64

# %%
del df

# %%
df = pd.read_csv("data/Austin_Sold.csv")

# %%
df.head()
# Out:
#                                         property_url   mls  mls_id status  \
# 0  https://www.realtor.com/realestateandhomes-det...  CTTX  537428   SOLD
# 1  https://www.realtor.com/realestateandhomes-det...  CTTX  540753   SOLD
# 2  https://www.realtor.com/realestateandhomes-det...  CTTX  534869   SOLD
# 3  https://www.realtor.com/realestateandhomes-det...  HLTX  168089   SOLD
# 4  https://www.realtor.com/realestateandhomes-det...  CTTX  538666   SOLD
#
#                                                 text          style  \
# 0  fabulous single story home near Domain and eas...  SINGLE_FAMILY
# 1  HERE'S AN OPPORTUNITY YOU DON'T WANT TO MISS.....  SINGLE_FAMILY
# 2  PRICE IMPROVEMENT! Enjoy living in the heart o...  SINGLE_FAMILY
# 3  Amazing Find In Cuernavaca w/ Hot Tub & Pool. ...  SINGLE_FAMILY
# 4  This is well-maintained and lovingly owned dup...   MULTI_FAMILY
#
#           full_street_line               street    unit    city state  \
# 0       12803 Irongate Ave   12803 Irongate Ave     NaN  Austin    TX
# 1           1403 Minnie Dr       1403 Minnie Dr     NaN  Austin    TX
# 2      6004 Open Range Trl  6004 Open Range Trl     NaN  Austin    TX
# 3         2814 Saratoga Dr     2814 Saratoga Dr     NaN  Austin    TX
# 4  918 Fieldwood Dr Unit A     918 Fieldwood Dr  Unit A  Austin    TX
#
#    zip_code  beds  full_baths  half_baths    sqft  year_built  days_on_mls  \
# 0     78727   3.0         2.0         NaN  1387.0      1977.0         75.0
# 1     78732   1.0         1.0         NaN   704.0      1982.0         34.0
# 2     78749   4.0         2.0         NaN  1886.0      1984.0        112.0
# 3     78733   3.0         2.0         NaN  1920.0      1982.0         95.0
# 4     78758   NaN         NaN         NaN  2420.0      1980.0         57.0
#
#    list_price   list_date  sold_price last_sold_date  assessed_value  \
# 0    375000.0  2024-03-16         NaN     2024-05-30        458786.0
# 1    440000.0  2024-04-18         NaN     2024-05-22        388865.0
# 2    497000.0  2024-02-23         NaN     2024-06-14        367134.0
# 3    950000.0  2024-03-27         NaN     2024-06-30        677461.0
# 4    499900.0  2024-03-28         NaN     2024-05-24             NaN
#
#    estimated_value  lot_sqft  price_per_sqft   latitude  longitude  \
# 0         375005.0    8246.0             NaN  30.421240 -97.694559
# 1         437000.0   12990.0             NaN  30.330755 -97.926471
# 2         497731.0   11543.0             NaN  30.221694 -97.867170
# 3         940000.0   15682.0             NaN  30.350446 -97.861136
# 4              NaN    7270.0             NaN  30.370544 -97.696869
#
#                                       neighborhoods  county  fips_code  \
# 0  Gracy Woods, Lamplight Village, Northwest Austin  Travis    48453.0
# 1                                  Northwest Austin  Travis    48453.0
# 2         Village at Western Oaks, Southwest Austin  Travis    48453.0
# 3                  West Austin, Austin Lake Estates  Travis    48453.0
# 4      North Austin, Quail Valley, Northwest Austin  Travis    48453.0
#
#    stories  hoa_fee  parking_garage                       agent  \
# 0      1.0      0.0             2.0                 Rita Snyder
# 1      1.0      0.0             NaN                Sylvia Muzzy
# 2      1.0      NaN             2.0         Rodgers Realty Team
# 3      1.0      NaN             NaN  null Don (Thomas) Johnston
# 4      1.0      0.0             1.0                Kim Mitchell
#
#                      agent_email  \
# 0          ritasnyder1@gmail.com
# 1  smuzzy@muzzypropertygroup.com
# 2           deerodgers@remax.net
# 3                            NaN
# 4     kim@kimmitchellrealtor.com
#
#                                         agent_phones  broker  broker_phone  \
# 0  [{'number': '5124682867', 'type': 'Mobile', 'e...     NaN           NaN
# 1  [{'number': '5126295434', 'type': 'Office', 'e...     NaN           NaN
# 2  [{'number': '8305572320', 'type': 'Office', 'e...     NaN           NaN
# 3                                                NaN     NaN           NaN
# 4  [{'number': '5126999244', 'type': None, 'ext':...     NaN           NaN
#
#    broker_website                                     nearby_schools  \
# 0             NaN  Pflugerville Independent School District, Chap...
# 1             NaN                Leander Independent School District
# 2             NaN  Trinity Charter School, Austin Independent Sch...
# 3             NaN                  Eanes Independent School District
# 4             NaN  Idea Public Schools, University Of Texas Unive...
#
#                                        primary_photo  \
# 0  http://ap.rdcpix.com/afe0492e10a406866f05db5ce...
# 1  http://ap.rdcpix.com/99d2b8808ea4b547b35a52da1...
# 2  http://ap.rdcpix.com/03a53e9c364a418ea8dab4367...
# 3  http://ap.rdcpix.com/2ec12f0dd45b5eadf66e3759b...
# 4  http://ap.rdcpix.com/610ef98c6d5d020da6fe41f08...
#
#                                           alt_photos
# 0  http://ap.rdcpix.com/afe0492e10a406866f05db5ce...
# 1  http://ap.rdcpix.com/99d2b8808ea4b547b35a52da1...
# 2  http://ap.rdcpix.com/03a53e9c364a418ea8dab4367...
# 3  http://ap.rdcpix.com/2ec12f0dd45b5eadf66e3759b...
# 4  http://ap.rdcpix.com/610ef98c6d5d020da6fe41f08...

# %% [markdown]
# # SOLD PROPERTY BASIC METRICS:

# %%
print("AUSTIN SOLD PROPERTY AVERAGES: \n")

print("Beds: "+ str(df.beds.mean().round(3)))
print("Full Baths: "+str(df.full_baths.mean().round(3)))
print("Half Baths: "+str(df.half_baths.mean().round(3)))
print("Square Feet: "+str(df.sqft.mean().round(3)))
print("Year Built: "+str(df.year_built.mean().round(3)))
print("Days on MLS: "+str(round(df.days_on_mls.mean())))
print("List Price: "+str(df.list_price.mean().round(3)))
print("Assessed Value: "+str(df.assessed_value.mean().round(3)))
print("Estimated Value: "+str(df.estimated_value.mean().round(3)))
print("Lot Square Feet: "+str(df.lot_sqft.mean().round(3)))
print("Price per Sq Feet: "+str((df.list_price.mean()/df.sqft.mean()).round(3)))
print("Stories: "+str(df.stories.mean().round(3)))
print("HOA Fees: "+str(df.hoa_fee.mean().round(3)))
print("Parking Garage: "+str(df.parking_garage.mean().round(3)))
# Out:
# AUSTIN SOLD PROPERTY AVERAGES:
#
# Beds: 3.295
# Full Baths: 2.346
# Half Baths: 1.051
# Square Feet: 2156.933
# Year Built: 2004.001
# Days on MLS: 84
# List Price: 739082.966
# Assessed Value: 511651.681
# Estimated Value: 613922.01
# Lot Square Feet: 21433.012
# Price per Sq Feet: 342.655
# Stories: 1.513
# HOA Fees: 61.108
# Parking Garage: 2.08

# %%
print("AUSTIN SOLD PROPERTY DATASET MEDIANS: \n")

print("Beds: "+ str(df.beds.median().round(3)))
print("Full Baths: "+str(df.full_baths.median().round(3)))
print("Half Baths: "+str(df.half_baths.median().round(3)))
print("Square Feet: "+str(df.sqft.median().round(3)))
print("Year Built: "+str(int(df.year_built.median())))
print("Days on MLS: "+str(df.days_on_mls.median().round(3)))
print("List Price: "+str(df.list_price.median().round(3)))
print("Assessed Value: "+str(df.assessed_value.median().round(3)))
print("Estimated Value: "+str(df.estimated_value.median().round(3)))
print("Lot Square Feet: "+str(df.lot_sqft.median().round(3)))
print("Price per Sq Feet: "+str(df.list_price.median()/df.sqft.median().round(3)))
print("Stories: "+str(df.stories.median().round(3)))
print("HOA Fees: "+str(df.hoa_fee.median().round(3)))
print("Parking Garage: "+str(df.parking_garage.median().round(3)))
# Out:
# AUSTIN SOLD PROPERTY DATASET MEDIANS:
#
# Beds: 3.0
# Full Baths: 2.0
# Half Baths: 1.0
# Square Feet: 1856.0
# Year Built: 2018
# Days on MLS: 60.0
# List Price: 494990.0
# Assessed Value: 441013.0
# Estimated Value: 510252.0
# Lot Square Feet: 7037.0
# Price per Sq Feet: 266.6971982758621
# Stories: 2.0
# HOA Fees: 17.0
# Parking Garage: 2.0

# %%
df["style"].value_counts()
# Out:
# style
# SINGLE_FAMILY                  6074
# CONDO                          2926
# MULTI_FAMILY                    413
# LAND                            248
# OTHER                           160
# CONDOS                           91
# MOBILE                           48
# TOWNHOMES                        16
# FARM                             10
# CONDO_TOWNHOME_ROWHOME_COOP       5
# COMMERCIAL                        1
# Name: count, dtype: int64

# %%
df["neighborhoods"].value_counts()
# Out:
# neighborhoods
# Bluff Springs, Southeast Austin                            732
# Southeast Austin                                           626
# Northeast Austin                                           324
# East Austin, Mueller                                       140
# Avery Ranch - Lakeline, Northwest Austin                   107
#                                                           ...
# Highland Lake Estates                                        1
# Westover Hills, Forest Mesa, Northwest Austin                1
# Bluff Springs, Southeast Austin, Chateau at Onion Creek      1
# Wimberly Lane                                                1
# MLK-183, Truman Heights, East Austin                         1
# Name: count, Length: 1186, dtype: int64
